# %%
#importing all the required libraries
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
#load the dataset
df=pd.read_csv('loan_prediction.csv')
df.head()
# Out:
#    Unnamed: 0  person_age person_gender person_education  person_income  \
# 0           0        22.0        female           Master        71948.0
# 1           2        25.0        female      High School        12438.0
# 2           3        23.0        female         Bachelor        79753.0
# 3           4        24.0          male           Master        66135.0
# 4           5        21.0        female      High School        12951.0
#
#    person_emp_exp person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0               0                  RENT    35000.0    PERSONAL          16.02
# 1               3              MORTGAGE     5500.0     MEDICAL          12.87
# 2               0                  RENT    35000.0     MEDICAL          15.23
# 3               1                  RENT    35000.0     MEDICAL          14.27
# 4               0                   OWN     2500.0     VENTURE           7.14
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.44                         3.0           635
# 2                 0.44                         2.0           675
# 3                 0.53                         4.0           586
# 4                 0.19                         2.0           532
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                             No            1
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
#dropping unnamed column
df=df.drop('Unnamed: 0',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      22000 non-null  float64
#  1   person_gender                   22000 non-null  object
#  2   person_education                22000 non-null  object
#  3   person_income                   22000 non-null  float64
#  4   person_emp_exp                  22000 non-null  int64
#  5   person_home_ownership           22000 non-null  object
#  6   loan_amnt                       22000 non-null  float64
#  7   loan_intent                     22000 non-null  object
#  8   loan_int_rate                   22000 non-null  float64
#  9   loan_percent_income             22000 non-null  float64
#  10  cb_person_cred_hist_length      22000 non-null  float64
#  11  credit_score                    22000 non-null  int64
#  12  previous_loan_defaults_on_file  22000 non-null  object
#  13  loan_status                     22000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 2.3+ MB

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    12000
# 1    10000
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  22000.000000   2.200000e+04    22000.000000  22000.000000
# mean      29.271273   7.594856e+04        6.746136   9952.005227
# std        7.209372   9.909231e+04        7.261292   6560.911884
# min       20.000000   8.000000e+03        0.000000    563.000000
# 25%       24.000000   4.286950e+04        1.000000   5000.000000
# 50%       27.000000   6.213300e+04        4.000000   8400.000000
# 75%       33.000000   8.966450e+04       10.000000  13650.000000
# max      144.000000   7.200766e+06      124.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   22000.000000         22000.000000                22000.000000
# mean       11.550081             0.158103                    6.902000
# std         3.025975             0.097802                    4.591552
# min         5.420000             0.000000                    2.000000
# 25%         9.450000             0.080000                    3.000000
# 50%        11.230000             0.140000                    5.000000
# 75%        13.640000             0.220000                    9.000000
# max        20.000000             0.630000                   30.000000
#
#        credit_score   loan_status
# count  22000.000000  22000.000000
# mean     633.847773      0.454545
# std       50.888104      0.497941
# min      418.000000      0.000000
# 25%      602.000000      0.000000
# 50%      640.000000      0.000000
# 75%      671.000000      1.000000
# max      850.000000      1.000000

# %%
df[df['person_age']>100]
# Out:
#        person_age person_gender person_education  person_income  \
# 9297        144.0        female        Associate      7200766.0
# 14930       116.0          male         Bachelor      5545545.0
# 15113       109.0          male      High School      5556399.0
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 9297              124              MORTGAGE     5000.0    PERSONAL
# 14930              93              MORTGAGE     3823.0     VENTURE
# 15113              85              MORTGAGE     6195.0     VENTURE
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 9297           12.73                  0.0                        25.0
# 14930          12.15                  0.0                        24.0
# 15113          12.58                  0.0                        22.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 9297            850                             No            0
# 14930           708                             No            0
# 15113           792                             No            0

# %%
df[df['person_age']<=0]
# Out:
# Empty DataFrame
# Columns: [person_age, person_gender, person_education, person_income, person_emp_exp, person_home_ownership, loan_amnt, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []

# %%
df=df[df['person_age']<=100]

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  21997.000000   2.199700e+04    21997.000000  21997.000000
# mean      29.258490   7.512687e+04        6.733327   9952.679775
# std        7.124086   6.918483e+04        7.175773   6561.095247
# min       20.000000   8.000000e+03        0.000000    563.000000
# 25%       24.000000   4.286500e+04        1.000000   5000.000000
# 50%       27.000000   6.213000e+04        4.000000   8400.000000
# 75%       33.000000   8.965500e+04       10.000000  13650.000000
# max       94.000000   2.448661e+06       76.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   21997.000000         21997.000000                21997.000000
# mean       11.549953             0.158124                    6.899714
# std         3.026160             0.097791                    4.587666
# min         5.420000             0.000000                    2.000000
# 25%         9.450000             0.080000                    3.000000
# 50%        11.230000             0.140000                    5.000000
# 75%        13.640000             0.220000                    9.000000
# max        20.000000             0.630000                   30.000000
#
#        credit_score   loan_status
# count  21997.000000  21997.000000
# mean     633.827386      0.454607
# std       50.857061      0.497947
# min      418.000000      0.000000
# 25%      602.000000      0.000000
# 50%      640.000000      0.000000
# 75%      671.000000      1.000000
# max      784.000000      1.000000

# %%
#checking outliers in person_age
sns.boxplot(y='person_age',data=df)
# Out:
# <Axes: ylabel='person_age'>

# %%
sns.boxplot(y='person_income',data=df)
# Out:
# <Axes: ylabel='person_income'>

# %%
df.info()
df['loan_status'].value_counts()
df['loan_status']=[1 if i>=700 else 0 for i in df['credit_score']]
df['loan_status'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21997 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      21997 non-null  float64
#  1   person_gender                   21997 non-null  object
#  2   person_education                21997 non-null  object
#  3   person_income                   21997 non-null  float64
#  4   person_emp_exp                  21997 non-null  int64
#  5   person_home_ownership           21997 non-null  object
#  6   loan_amnt                       21997 non-null  float64
#  7   loan_intent                     21997 non-null  object
#  8   loan_int_rate                   21997 non-null  float64
#  9   loan_percent_income             21997 non-null  float64
#  10  cb_person_cred_hist_length      21997 non-null  float64
#  11  credit_score                    21997 non-null  int64
#  12  previous_loan_defaults_on_file  21997 non-null  object
#  13  loan_status                     21997 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 2.5+ MB
# loan_status
# 0    20400
# 1     1597
# Name: count, dtype: int64

# %%
cleaned=df.copy()
cleaned.to_csv('cleaned.csv')

# %%
from sklearn.preprocessing import LabelEncoder
obj=LabelEncoder()
for i in df.columns:
    if df[i].dtype==object:
        df[i]=obj.fit_transform(df[i])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21997 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      21997 non-null  float64
#  1   person_gender                   21997 non-null  int64
#  2   person_education                21997 non-null  int64
#  3   person_income                   21997 non-null  float64
#  4   person_emp_exp                  21997 non-null  int64
#  5   person_home_ownership           21997 non-null  int64
#  6   loan_amnt                       21997 non-null  float64
#  7   loan_intent                     21997 non-null  int64
#  8   loan_int_rate                   21997 non-null  float64
#  9   loan_percent_income             21997 non-null  float64
#  10  cb_person_cred_hist_length      21997 non-null  float64
#  11  credit_score                    21997 non-null  int64
#  12  previous_loan_defaults_on_file  21997 non-null  int64
#  13  loan_status                     21997 non-null  int64
# dtypes: float64(6), int64(8)
# memory usage: 2.5 MB

# %%
X=df.iloc[:,:-1]
y=df['loan_status']

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
model=RandomForestClassifier(n_estimators=200,max_depth=10)
model.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200)

# %%
ypred=model.predict(Xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 1.0

# %%
with open('model.pkl','wb') as file:
    pickle.dump(model,file)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.7.2'

# %%
df['credit_score']
# Out:
# 0        561
# 1        635
# 2        675
# 3        586
# 4        532
#         ...
# 21995    645
# 21996    621
# 21997    668
# 21998    604
# 21999    628
# Name: credit_score, Length: 21997, dtype: int64
